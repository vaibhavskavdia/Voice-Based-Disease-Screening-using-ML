# %% [markdown]
# librosa: Library for audio analysis and feature extraction (like MFCC, ZCR).
# librosa.display: Helper module to plot waveforms and spectrograms.

# %%
import librosa
import librosa.display
import matplotlib.pyplot as plt
import numpy as np
import random
import pandas as pd

# %%
from src.Voice_Based_Disease_Screening_using_ML.feature_extraction import audio_files
# Out:
# Total audio files found: 684
# Sample files:
# /Users/vaibhavkavdia/Desktop/Projects_for_Resume/Medical/Voice-Based-Disease-Screening-using-ML//Coswara-Data/20200413/20200413/vK2bLRNzllXNeyOMudnNSL5cfpG2/counting-normal.wav
# /Users/vaibhavkavdia/Desktop/Projects_for_Resume/Medical/Voice-Based-Disease-Screening-using-ML//Coswara-Data/20200413/20200413/vK2bLRNzllXNeyOMudnNSL5cfpG2/vowel-o.wav
# /Users/vaibhavkavdia/Desktop/Projects_for_Resume/Medical/Voice-Based-Disease-Screening-using-ML//Coswara-Data/20200413/20200413/vK2bLRNzllXNeyOMudnNSL5cfpG2/vowel-a.wav
# /Users/vaibhavkavdia/Desktop/Projects_for_Resume/Medical/Voice-Based-Disease-Screening-using-ML//Coswara-Data/20200413/20200413/vK2bLRNzllXNeyOMudnNSL5cfpG2/vowel-e.wav
# /Users/vaibhavkavdia/Desktop/Projects_for_Resume/Medical/Voice-Based-Disease-Screening-using-ML//Coswara-Data/20200413/20200413/vK2bLRNzllXNeyOMudnNSL5cfpG2/breathing-shallow.wav
# ...

# %%
random_file = random.choice(audio_files)
print(f"selected:{random_file}")
# Out:
# selected:/Users/vaibhavkavdia/Desktop/Projects_for_Resume/Medical/Voice-Based-Disease-Screening-using-ML//Coswara-Data/20200413/20200413/G3iIP9QRHPTItOsK6lpEMd6IQKw1/vowel-o.wav

# %%
y, sr = librosa.load(random_file, sr=22050)

# Plot waveform
plt.figure(figsize=(12, 4))
librosa.display.waveshow(y, sr=sr)
plt.title("Waveform")
plt.xlabel("Time (s)")
plt.ylabel("Amplitude")
plt.show()

# Plot MFCCs
mfccs = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=13)
plt.figure(figsize=(10, 4))
librosa.display.specshow(mfccs, x_axis='time', sr=sr)
plt.colorbar()
plt.title("MFCCs")
plt.tight_layout()
plt.show()

# %%
# !pip install tqdm
# Out:
# ...
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# ...

# %%
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 df.head()
#
# NameError: name 'df' is not defined
